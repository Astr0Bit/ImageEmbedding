# %% [markdown]
# ### Testing the ImageEmbedding class

# %%
import sys

if "../" not in sys.path:
    sys.path.append("../")

from image_embedding import ImageEmbedding

ie = ImageEmbedding()
IMAGE_FILENAMES = ["../images/00-puppy.jpg",
                   "../images/dog_backpack.png"]

ie.predict_images(IMAGE_FILENAMES)

# %%
IMAGE_FILENAMES = ["../images/00-puppy.jpg",
                   "../images/gorilla.jpg"]

ie.predict_images(IMAGE_FILENAMES)

# %%
IMAGE_FILENAMES = ["../images/00-puppy.jpg",
                   "../images/bricks.jpg"]

ie.predict_images(IMAGE_FILENAMES)

# %%
IMAGE_FILENAMES = ["../images/gorilla.jpg",
                   "../images/bricks.jpg"]

ie.predict_images(IMAGE_FILENAMES)
