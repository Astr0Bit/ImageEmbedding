# %% [markdown]
# ### Testing the ImageEmebedding class on video

# %%
import sys

if "../" not in sys.path:
    sys.path.append("../")

from image_embedding import ImageEmbedding

ie = ImageEmbedding()

# %%
help(ImageEmbedding)
# Out:
# Help on class ImageEmbedding in module image_embedding:
#
# class ImageEmbedding(builtins.object)
#  |  ImageEmbedding(l2_normalize: bool = True, quantize: bool = True) -> None
#  |
#  |  Class for performing image embedding using Google's MediaPipe library.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, l2_normalize: bool = True, quantize: bool = True) -> None
#  |      Args:
#  |          l2_normalize: Whether to L2 normalize the embeddings.
#  |          quantize: Whether to quantize the embeddings.
#  |
#  |      Returns:
#  |          None
#  |
#  |  predict_images(self, IMAGE_FILENAMES: list | tuple[str, str]) -> None
#  |      Predicts the embeddings of the input images.
#  |
#  |      Args:
#  |          image_paths: A list of paths to the input images.
#  |
#  |      Returns:
#  |          None
#  |
#  |  predict_video(self, VIDEO_FILENAMES: list | tuple[str, str], save: bool = False, output_file_name: str = 'similarity_side_by_side') -> None
# ...

# %%
VIDEO_FILENAMES = ["../videos/dog_1.mp4", "../videos/dog_2.mp4"]
ie.predict_video(VIDEO_FILENAMES, save=True, output_file_name="dog_1_dog_2")
# Out:
# Frames found in ../videos/dog_1.mp4: 269
# Frames found in ../videos/dog_2.mp4: 415
# Adjusting frames for both videos. New number of frames: 269

# %%
VIDEO_FILENAMES = ["../videos/kangaroo_1.mp4", "../videos/kangaroo_2.mp4"]
ie.predict_video(VIDEO_FILENAMES, save=True, output_file_name="kangaroo_1_kangaroo_2")
# Out:
# Frames found in ../videos/kangaroo_1.mp4: 94
# Frames found in ../videos/kangaroo_2.mp4: 424
# Adjusting frames for both videos. New number of frames: 94

# %%
VIDEO_FILENAMES = ["../videos/kangaroo_3.mp4", "../videos/kangaroo_4.mp4"]
ie.predict_video(VIDEO_FILENAMES, save=True, output_file_name="kangaroo_3_kangaroo_4")
# Out:
# Frames found in ../videos/kangaroo_3.mp4: 395
# Frames found in ../videos/kangaroo_4.mp4: 651
# Adjusting frames for both videos. New number of frames: 395
